# %% [markdown]
# # JEROME INFANT SALETH.N.A
# ## The spark foundatation
# ## DATA SCIENCE AND BUSINESS ANALYTICS
# ### TASK #3
# # GRIPMAY21

# %% [markdown]
# ### OBJECTIVE:
#    1) Perform "Exploratory Data Analysis"on dataset "Sample Superstore"
#    2) As a business manager ,try to find out the weak area where you can work to make more profit
#    3) what all the business problems you can derive by exploring the data?

# %%
#Importing Libraries
import pandas as pd
import numpy as np  
import seaborn as sns
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
#Importing dataset
data=pd.read_csv("SampleSuperstore.csv")

# %%
#displaying top five dataset
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
#list the columns in the dataset
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#shape of the dataset
data.shape
# Out:
# (9994, 13)

# %%
#information about varibles observations and types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
# Ship Mode       9994 non-null object
# Segment         9994 non-null object
# Country         9994 non-null object
# City            9994 non-null object
# State           9994 non-null object
# Postal Code     9994 non-null int64
# Region          9994 non-null object
# Category        9994 non-null object
# Sub-Category    9994 non-null object
# Sales           9994 non-null float64
# Quantity        9994 non-null int64
# Discount        9994 non-null float64
# Profit          9994 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#check the unique categories of the varibels 
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#Display the categories in each variables
data['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
data['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
data['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
data['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
data['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
data['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
#drop useless variable
data.drop({"Country","Postal Code"},axis=1,inplace=True)

# %%
#clean the data
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#summary statistics
data.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
#sorting w.r.t a variable
data_sort=data.sort_values(by='Profit',ascending=False).head()
data_sort.head()
# Out:
#            Ship Mode    Segment         City       State   Region  \
# 6826  Standard Class  Corporate    Lafayette     Indiana  Central
# 8153     First Class   Consumer      Seattle  Washington     West
# 4190  Standard Class   Consumer       Newark    Delaware     East
# 9039  Standard Class   Consumer      Detroit    Michigan  Central
# 4098  Standard Class   Consumer  Minneapolis   Minnesota  Central
#
#              Category Sub-Category     Sales  Quantity  Discount     Profit
# 6826       Technology      Copiers  17499.95         5       0.0  8399.9760
# 8153       Technology      Copiers  13999.96         4       0.0  6719.9808
# 4190       Technology      Copiers  10499.97         3       0.0  5039.9856
# 9039  Office Supplies      Binders   9892.74        13       0.0  4946.3700
# 4098  Office Supplies      Binders   9449.95         5       0.0  4630.4755

# %%
#maximum and minimum profit in each categories
def min_max_values(col):
    top=data[col].idxmax()
    top_obs=pd.DataFrame(data.loc[top])
    
    bottom=data[col].idxmin()
    bot_obs=pd.DataFrame(data.loc[bottom])
    
    min_max_obs=pd.concat([top_obs,bot_obs],axis=1)
    
    return  min_max_obs

# %%
min_max_values('Profit')
# Out:
#                         6826            7772
# Ship Mode     Standard Class  Standard Class
# Segment            Corporate        Consumer
# City               Lafayette       Lancaster
# State                Indiana            Ohio
# Region               Central            East
# Category          Technology      Technology
# Sub-Category         Copiers        Machines
# Sales                  17500         4499.98
# Quantity                   5               5
# Discount                   0             0.7
# Profit               8399.98        -6599.98

# %%
#pairplot of all possible numerical variable with single categorical varibale
sns.pairplot(data,hue='Region')

# %%
sns.pairplot(data,hue='Category')

# %%
sns.pairplot(data,hue='Sub-Category')

# %%
sub=data.groupby("Sub-Category")['Sales','Profit'].sum()
sub
# Out:
#                     Sales      Profit
# Sub-Category
# Accessories   167380.3180  41936.6357
# Appliances    107532.1610  18138.0054
# Art            27118.7920   6527.7870
# Binders       203412.7330  30221.7633
# Bookcases     114879.9963  -3472.5560
# Chairs        328449.1030  26590.1663
# Copiers       149528.0300  55617.8249
# Envelopes      16476.4020   6964.1767
# Fasteners       3024.2800    949.5182
# Furnishings    91705.1640  13059.1436
# Labels         12486.3120   5546.2540
# Machines      189238.6310   3384.7569
# Paper          78479.2060  34053.5693
# Phones        330007.0540  44515.7306
# Storage       223843.6080  21278.8264
# Supplies       46673.5380  -1189.0995
# Tables        206965.5320 -17725.4811

# %%
sub.plot.bar(color=['green','magenta'],figsize=(14,7))
plt.title("profit vs sales")
plt.show()

# %%
sub[sub["Profit"]<0]
# Out:
#                     Sales      Profit
# Sub-Category
# Bookcases     114879.9963  -3472.5560
# Supplies       46673.5380  -1189.0995
# Tables        206965.5320 -17725.4811

# %%
sns.relplot(x='Profit',y='Sales',hue='Sub-Category',data=data)

# %%
reg=data.groupby("Region")['Sales','Profit'].sum()

reg.plot.bar(color=['orange','magenta'],figsize=(14,7))

# %%
sns.relplot(x='Profit',y='Sales',hue='Region',data=data)

# %%
ship=data.groupby("Ship Mode")['Sales','Profit'].sum()
ship.plot.bar(color=['orange','magenta'],figsize=(14,7))

# %%
sns.relplot(x='Profit',y='Sales',hue='Ship Mode',data=data)

# %%
seg=data.groupby("Segment")['Sales','Profit'].sum()
seg.plot.bar(color=['orange','magenta'],figsize=(14,7))

# %%
sns.relplot(x='Profit',y='Sales',hue='Segment',data=data)

# %%
cat=data.groupby("Category")['Sales','Profit'].sum()
cat.plot.bar(color=['orange','magenta'],figsize=(14,7))

# %%
sns.relplot(x='Profit',y='Sales',hue='Category',data=data)

# %%
state=data.groupby("State")['Sales','Profit'].sum()
state.plot.bar(color=['orange','magenta'],figsize=(14,7))

# %%
sns.relplot(x='Profit',y='Sales',hue='State',data=data)

# %%
 state[state["Sales"]==state["Sales"].max()]
# Out:
#                   Sales      Profit
# State
# California  457687.6315  76381.3871

# %%
state[state["Sales"]==state["Sales"].min()]
# Out:
#                Sales    Profit
# State
# North Dakota  919.91  230.1497

# %%
state[state["Profit"]==state["Profit"].max()]
# Out:
#                   Sales      Profit
# State
# California  457687.6315  76381.3871

# %%
state[state["Profit"]==state["Profit"].min()]
# Out:
#              Sales      Profit
# State
# Texas  170188.0458 -25729.3563

# %%
state[state["Profit"]<0]
# Out:
#                       Sales      Profit
# State
# Arizona          35282.0010  -3427.9246
# Colorado         32108.1180  -6527.8579
# Florida          89473.7080  -3399.3017
# Illinois         80166.1010 -12607.8870
# North Carolina   55603.1640  -7490.9122
# Ohio             78258.1360 -16971.3766
# Oregon           17431.1500  -1190.4705
# Pennsylvania    116511.9140 -15559.9603
# Tennessee        30661.8730  -5341.6936
# Texas           170188.0458 -25729.3563

# %%
city=data.groupby("City")['Sales','Profit'].sum()
city.plot.bar(color=['orange','magenta'],figsize=(14,7))

# %%
sns.relplot(x='Profit',y='Sales',hue='City',data=data)

# %%
 city[city["Sales"]==city["Sales"].max()]
# Out:
#                     Sales      Profit
# City
# New York City  256368.161  62036.9837

# %%
 city[city["Sales"]==city["Sales"].min()]
# Out:
#          Sales  Profit
# City
# Abilene  1.392 -3.7584

# %%
city[city["Profit"]==city["Profit"].max()]
# Out:
#                     Sales      Profit
# City
# New York City  256368.161  62036.9837

# %%
city[city["Profit"]==city["Profit"].min()]
# Out:
#                    Sales      Profit
# City
# Philadelphia  109077.013 -13837.7674

# %%
city[city["Profit"]<0]
# Out:
#                Sales    Profit
# City
# Abilene       1.3920   -3.7584
# Akron      2729.9860 -186.6356
# Allen       290.2060  -39.8775
# Allentown   853.2520 -226.4504
# Altoona      20.4510   -1.1835
# ...              ...       ...
# Waco        606.1072 -520.1034
# Wheeling   1946.9660 -107.3962
# Wilson      368.7320  -14.3360
# York        817.9780 -102.1692
# Yuma        840.8650 -465.9909
#
# [116 rows x 2 columns]

# %%
#histogram for numerical varibale
plt.hist(data['Profit'],10)
# Out:
# (array([1.000e+00, 2.000e+00, 4.000e+00, 3.400e+01, 9.907e+03, 3.500e+01,
#         5.000e+00, 4.000e+00, 1.000e+00, 1.000e+00]),
#  array([-6599.978 , -5099.9826, -3599.9872, -2099.9918,  -599.9964,
#           899.999 ,  2399.9944,  3899.9898,  5399.9852,  6899.9806,
#          8399.976 ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(data['Profit'],bins=50)

# %%
plt.hist(data['Sales'],10)
# Out:
# (array([9.876e+03, 9.100e+01, 1.300e+01, 6.000e+00, 5.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([4.44000000e-01, 2.26424760e+03, 4.52805120e+03, 6.79185480e+03,
#         9.05565840e+03, 1.13194620e+04, 1.35832656e+04, 1.58470692e+04,
#         1.81108728e+04, 2.03746764e+04, 2.26384800e+04]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(data['Sales'],bins=10)

# %%
plt.hist(data['Discount'],10)
# Out:
# (array([4798.,  146., 3657.,  227.,   27.,  217.,   66.,  138.,  418.,
#          300.]),
#  array([0.  , 0.08, 0.16, 0.24, 0.32, 0.4 , 0.48, 0.56, 0.64, 0.72, 0.8 ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(data['Discount'],bins=10)

# %%
plt.hist(data['Quantity'],10)
# Out:
# (array([3301., 2409., 1191., 1802.,  606.,  257.,  315.,   34.,   23.,
#           56.]),
#  array([ 1. ,  2.3,  3.6,  4.9,  6.2,  7.5,  8.8, 10.1, 11.4, 12.7, 14. ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(data['Quantity'],bins=10)

# %%
#select all numerical variable
data_num=data.select_dtypes(include=['float64','int64'])
data_num.head()
# Out:
#       Sales  Quantity  Discount    Profit
# 0  261.9600         2      0.00   41.9136
# 1  731.9400         3      0.00  219.5820
# 2   14.6200         2      0.00    6.8714
# 3  957.5775         5      0.45 -383.0310
# 4   22.3680         2      0.20    2.5164

# %%
data_num.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000930F0DEB88>,
# ...
#       dtype=object)

# %%
data_corr=data_num.corr()['Profit'][:-1]
data_corr
# Out:
# Sales       0.479064
# Quantity    0.066253
# Discount   -0.219487
# Name: Profit, dtype: float64

# %%
#correlation plot using pairplot
for i in range(0,len(data_num.columns),4):
      sns.pairplot(data_num,y_vars=['Profit'],x_vars=data_num.columns[i:1+5])

# %%
correlation=data.corr()
correlation
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)

# %%
sns.pairplot(data)

# %%
sns.regplot(data['Profit'],data['Discount'])

# %%
sns.regplot(data['Profit'],data['Quantity'])

# %%
sns.regplot(data['Profit'],data['Sales'])

# %%
#box plot for profit and some categorical variable
box1=sns.boxplot(x='Segment',y='Profit',data=data)

# %%
box1=sns.boxplot(x='Ship Mode',y='Profit',data=data)

# %%
box1=sns.boxplot(x='State',y='Profit',data=data)

# %%
box1=sns.boxplot(x='City',y='Profit',data=data)

# %%
box1=sns.boxplot(x='Category',y='Profit',data=data)

# %%
box1=sns.boxplot(x='Sub-Category',y='Profit',data=data)

# %%
box1=sns.boxplot(x='Region',y='Profit',data=data)

# %% [markdown]
# ### Conclusion

# %%
#From the above graphs and statistical analysis one can easily straight away came to conclusion easier

# %%
#least sales=Fasterners,south region,same day,consumer segment,office supplies,Abilence city,north Dakota

# %%
#least profit=Tables,central region,furniture,Philadelphia,texas

# %%
#highest profit=west region

# %%
#highest sales=west region,standard class,Home office segment
